# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.preprocessing import StandardScaler

# %%
## !pip install category_encoders

# %%
from category_encoders import BinaryEncoder, TargetEncoder

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
sns.set(rc={'figure.figsize': (11.7, 8.27)})

# %%
##
pd.set_option('display.max_columns', None)

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Чтение данных

# %%
data = pd.read_csv('data.csv')

# %%
data.head()
# Out:
#    Gender      Customer Type  Age   Type of Travel     Class  Flight Distance  \
# 0    Male     Loyal Customer   13  Personal Travel  Eco Plus              460
# 1    Male  disloyal Customer   25  Business travel  Business              235
# 2  Female     Loyal Customer   26  Business travel  Business             1142
# 3  Female     Loyal Customer   25  Business travel  Business              562
# 4    Male     Loyal Customer   61  Business travel  Business              214
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease of Online booking  Gate location  Food and drink  Online boarding  \
# 0                       3              1               5                3
# 1                       3              3               1                3
# 2                       2              2               5                5
# 3                       5              5               2                2
# 4                       3              3               4                5
#
#    Seat comfort  Inflight entertainment  On-board service  Leg room service  \
# 0             5                       5                 4                 3
# 1             1                       1                 1                 5
# 2             5                       5                 4                 3
# 3             2                       2                 2                 5
# 4             5                       3                 3                 4
#
#    Baggage handling  Checkin service  Cleanliness  Departure Delay in Minutes  \
# 0                 4                4            5                          25
# 1                 3                1            1                           1
# 2                 4                4            5                           0
# 3                 3                1            2                          11
# 4                 4                3            3                           0
#
#    Arrival Delay in Minutes  satisfaction
# 0                      18.0         False
# 1                       6.0         False
# 2                       0.0          True
# 3                       9.0         False
# 4                       0.0          True

# %%
X = data.drop(columns='satisfaction')
y = data['satisfaction']

# %%
data.groupby('satisfaction', as_index=False).agg({'Gender': 'count'})
# Out:
#    satisfaction  Gender
# 0         False   73452
# 1          True   56428

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %%
X_y_train = X_train.copy(deep=True)
X_y_train['y'] = y_train

# %% [markdown]
# # Исследовательский анализ данных

# %%
##
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 22 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Gender                             129880 non-null  object
#  1   Customer Type                      129880 non-null  object
#  2   Age                                129880 non-null  int64
#  3   Type of Travel                     129880 non-null  object
#  4   Class                              129880 non-null  object
#  5   Flight Distance                    129880 non-null  int64
#  6   Inflight wifi service              129880 non-null  int64
#  7   Departure/Arrival time convenient  129880 non-null  int64
#  8   Ease of Online booking             129880 non-null  int64
#  9   Gate location                      129880 non-null  int64
#  10  Food and drink                     129880 non-null  int64
#  11  Online boarding                    129880 non-null  int64
#  12  Seat comfort                       129880 non-null  int64
#  13  Inflight entertainment             129880 non-null  int64
#  14  On-board service                   129880 non-null  int64
#  15  Leg room service                   129880 non-null  int64
#  16  Baggage handling                   129880 non-null  int64
#  17  Checkin service                    129880 non-null  int64
#  18  Cleanliness                        129880 non-null  int64
#  19  Departure Delay in Minutes         129880 non-null  int64
#  20  Arrival Delay in Minutes           129487 non-null  float64
#  21  satisfaction                       129880 non-null  bool
# dtypes: bool(1), float64(1), int64(16), object(4)
# memory usage: 20.9+ MB

# %%
##
data.describe()
# Out:
#                  Age  Flight Distance  Inflight wifi service  \
# count  129880.000000    129880.000000          129880.000000
# mean       39.427957      1190.316392               2.728696
# std        15.119360       997.452477               1.329340
# min         7.000000        31.000000               0.000000
# 25%        27.000000       414.000000               2.000000
# 50%        40.000000       844.000000               3.000000
# 75%        51.000000      1744.000000               4.000000
# max        85.000000      4983.000000               5.000000
#
#        Departure/Arrival time convenient  Ease of Online booking  \
# count                      129880.000000           129880.000000
# mean                            3.057599                2.756876
# std                             1.526741                1.401740
# min                             0.000000                0.000000
# 25%                             2.000000                2.000000
# 50%                             3.000000                3.000000
# 75%                             4.000000                4.000000
# max                             5.000000                5.000000
#
#        Gate location  Food and drink  Online boarding   Seat comfort  \
# count  129880.000000   129880.000000    129880.000000  129880.000000
# mean        2.976925        3.204774         3.252633       3.441361
# std         1.278520        1.329933         1.350719       1.319289
# min         0.000000        0.000000         0.000000       0.000000
# 25%         2.000000        2.000000         2.000000       2.000000
# 50%         3.000000        3.000000         3.000000       4.000000
# 75%         4.000000        4.000000         4.000000       5.000000
# max         5.000000        5.000000         5.000000       5.000000
#
#        Inflight entertainment  On-board service  Leg room service  \
# count           129880.000000     129880.000000     129880.000000
# mean                 3.358077          3.383023          3.350878
# std                  1.334049          1.287099          1.316252
# min                  0.000000          0.000000          0.000000
# 25%                  2.000000          2.000000          2.000000
# 50%                  4.000000          4.000000          4.000000
# 75%                  4.000000          4.000000          4.000000
# max                  5.000000          5.000000          5.000000
#
#        Baggage handling  Checkin service    Cleanliness  \
# count     129880.000000    129880.000000  129880.000000
# mean           3.632114         3.306267       3.286326
# std            1.180025         1.266185       1.313682
# min            1.000000         0.000000       0.000000
# 25%            3.000000         3.000000       2.000000
# 50%            4.000000         3.000000       3.000000
# 75%            5.000000         4.000000       4.000000
# max            5.000000         5.000000       5.000000
#
#        Departure Delay in Minutes  Arrival Delay in Minutes
# count               129880.000000             129487.000000
# mean                    14.713713                 15.091129
# std                     38.071126                 38.465650
# min                      0.000000                  0.000000
# 25%                      0.000000                  0.000000
# 50%                      0.000000                  0.000000
# 75%                     12.000000                 13.000000
# max                   1592.000000               1584.000000

# %%
##
data.describe(include=['object', 'bool'])
# Out:
#         Gender   Customer Type   Type of Travel     Class satisfaction
# count   129880          129880           129880    129880       129880
# unique       2               2                2         3            2
# top     Female  Loyal Customer  Business travel  Business        False
# freq     65899          106100            89693     62160        73452

# %%
##
data.describe(include='all')
# Out:
#         Gender   Customer Type            Age   Type of Travel     Class  \
# count   129880          129880  129880.000000           129880    129880
# unique       2               2            NaN                2         3
# top     Female  Loyal Customer            NaN  Business travel  Business
# freq     65899          106100            NaN            89693     62160
# mean       NaN             NaN      39.427957              NaN       NaN
# std        NaN             NaN      15.119360              NaN       NaN
# min        NaN             NaN       7.000000              NaN       NaN
# 25%        NaN             NaN      27.000000              NaN       NaN
# 50%        NaN             NaN      40.000000              NaN       NaN
# 75%        NaN             NaN      51.000000              NaN       NaN
# max        NaN             NaN      85.000000              NaN       NaN
#
#         Flight Distance  Inflight wifi service  \
# count     129880.000000          129880.000000
# unique              NaN                    NaN
# top                 NaN                    NaN
# freq                NaN                    NaN
# mean        1190.316392               2.728696
# std          997.452477               1.329340
# min           31.000000               0.000000
# 25%          414.000000               2.000000
# 50%          844.000000               3.000000
# 75%         1744.000000               4.000000
# max         4983.000000               5.000000
#
#         Departure/Arrival time convenient  Ease of Online booking  \
# count                       129880.000000           129880.000000
# unique                                NaN                     NaN
# top                                   NaN                     NaN
# freq                                  NaN                     NaN
# mean                             3.057599                2.756876
# std                              1.526741                1.401740
# min                              0.000000                0.000000
# 25%                              2.000000                2.000000
# 50%                              3.000000                3.000000
# 75%                              4.000000                4.000000
# max                              5.000000                5.000000
#
#         Gate location  Food and drink  Online boarding   Seat comfort  \
# count   129880.000000   129880.000000    129880.000000  129880.000000
# unique            NaN             NaN              NaN            NaN
# top               NaN             NaN              NaN            NaN
# freq              NaN             NaN              NaN            NaN
# mean         2.976925        3.204774         3.252633       3.441361
# std          1.278520        1.329933         1.350719       1.319289
# min          0.000000        0.000000         0.000000       0.000000
# 25%          2.000000        2.000000         2.000000       2.000000
# 50%          3.000000        3.000000         3.000000       4.000000
# 75%          4.000000        4.000000         4.000000       5.000000
# max          5.000000        5.000000         5.000000       5.000000
#
#         Inflight entertainment  On-board service  Leg room service  \
# count            129880.000000     129880.000000     129880.000000
# unique                     NaN               NaN               NaN
# top                        NaN               NaN               NaN
# freq                       NaN               NaN               NaN
# mean                  3.358077          3.383023          3.350878
# std                   1.334049          1.287099          1.316252
# min                   0.000000          0.000000          0.000000
# 25%                   2.000000          2.000000          2.000000
# 50%                   4.000000          4.000000          4.000000
# 75%                   4.000000          4.000000          4.000000
# max                   5.000000          5.000000          5.000000
#
#         Baggage handling  Checkin service    Cleanliness  \
# count      129880.000000    129880.000000  129880.000000
# unique               NaN              NaN            NaN
# top                  NaN              NaN            NaN
# freq                 NaN              NaN            NaN
# mean            3.632114         3.306267       3.286326
# std             1.180025         1.266185       1.313682
# min             1.000000         0.000000       0.000000
# 25%             3.000000         3.000000       2.000000
# 50%             4.000000         3.000000       3.000000
# 75%             5.000000         4.000000       4.000000
# max             5.000000         5.000000       5.000000
#
#         Departure Delay in Minutes  Arrival Delay in Minutes satisfaction
# count                129880.000000             129487.000000       129880
# unique                         NaN                       NaN            2
# top                            NaN                       NaN        False
# freq                           NaN                       NaN        73452
# mean                     14.713713                 15.091129          NaN
# std                      38.071126                 38.465650          NaN
# min                       0.000000                  0.000000          NaN
# 25%                       0.000000                  0.000000          NaN
# 50%                       0.000000                  0.000000          NaN
# 75%                      12.000000                 13.000000          NaN
# max                    1592.000000               1584.000000          NaN

# %%
X_y_train.isna().any()
# Out:
# Gender                               False
# Customer Type                        False
# Age                                  False
# Type of Travel                       False
# Class                                False
# Flight Distance                      False
# Inflight wifi service                False
# Departure/Arrival time convenient    False
# Ease of Online booking               False
# Gate location                        False
# Food and drink                       False
# Online boarding                      False
# Seat comfort                         False
# Inflight entertainment               False
# On-board service                     False
# Leg room service                     False
# Baggage handling                     False
# Checkin service                      False
# Cleanliness                          False
# Departure Delay in Minutes           False
# Arrival Delay in Minutes              True
# y                                    False
# dtype: bool

# %%
X_y_train[X_y_train['Arrival Delay in Minutes'].isna()]['Arrival Delay in Minutes']
# Out:
# 107098   NaN
# 84637    NaN
# 115591   NaN
# 87261    NaN
# 117195   NaN
#           ..
# 79013    NaN
# 99814    NaN
# 9481     NaN
# 16881    NaN
# 71557    NaN
# Name: Arrival Delay in Minutes, Length: 294, dtype: float64

# %%
sns.histplot(X_y_train['Arrival Delay in Minutes'][X_y_train['Arrival Delay in Minutes'] < 100]);

# %%
sns.histplot(X_y_train['Arrival Delay in Minutes'][(X_y_train['Arrival Delay in Minutes'] < 100) & (X_y_train['Arrival Delay in Minutes'] > 0)]);

# %%
##
X_y_train['Arrival Delay in Minutes'].mean()
# Out:
# 15.107737139091396

# %%
## решили заполнить пустые значения наобум, как я понял 5
X_y_train['Arrival Delay in Minutes'] = X_y_train['Arrival Delay in Minutes'].fillna(5)

# %%
##
X_y_train['Arrival Delay in Minutes'].mean()
# Out:
# 15.077230263833282

# %%
## пропусков не осталось
X_y_train.isna().any()
# Out:
# Gender                               False
# Customer Type                        False
# Age                                  False
# Type of Travel                       False
# Class                                False
# Flight Distance                      False
# Inflight wifi service                False
# Departure/Arrival time convenient    False
# Ease of Online booking               False
# Gate location                        False
# Food and drink                       False
# Online boarding                      False
# Seat comfort                         False
# Inflight entertainment               False
# On-board service                     False
# Leg room service                     False
# Baggage handling                     False
# Checkin service                      False
# Cleanliness                          False
# Departure Delay in Minutes           False
# Arrival Delay in Minutes             False
# y                                    False
# dtype: bool

# %%
sns.histplot(X_y_train['y']);

# %%
##
X_y_train.groupby('y').Class.agg({'count'}).plot.pie(y='count', title='Удовлетворен ли пассажир:');

# %%
corr_matrix = X_y_train.corr()
corr_matrix ##
# Out:
#                                         Age  Flight Distance  \
# Age                                1.000000         0.098764
# Flight Distance                    0.098764         1.000000
# Inflight wifi service              0.015072         0.004938
# Departure/Arrival time convenient  0.035957        -0.018508
# Ease of Online booking             0.021483         0.063436
# Gate location                     -0.000824         0.005740
# Food and drink                     0.023406         0.055859
# Online boarding                    0.208399         0.211447
# Seat comfort                       0.160770         0.156211
# Inflight entertainment             0.074734         0.128991
# On-board service                   0.057528         0.113503
# Leg room service                   0.038206         0.137181
# Baggage handling                  -0.050065         0.067924
# Checkin service                    0.034467         0.075491
# Cleanliness                        0.054714         0.092565
# Departure Delay in Minutes        -0.008189         0.003788
# Arrival Delay in Minutes          -0.010931        -0.000151
# y                                  0.134074         0.297777
#
#                                    Inflight wifi service  \
# Age                                             0.015072
# Flight Distance                                 0.004938
# Inflight wifi service                           1.000000
# Departure/Arrival time convenient               0.347605
# Ease of Online booking                          0.715012
# Gate location                                   0.340091
# Food and drink                                  0.133316
# Online boarding                                 0.458714
# Seat comfort                                    0.122114
# Inflight entertainment                          0.209914
# On-board service                                0.121420
# Leg room service                                0.159570
# Baggage handling                                0.121047
# Checkin service                                 0.043056
# Cleanliness                                     0.130730
# Departure Delay in Minutes                     -0.016020
# Arrival Delay in Minutes                       -0.017754
# y                                               0.283292
#
#                                    Departure/Arrival time convenient  \
# Age                                                         0.035957
# Flight Distance                                            -0.018508
# Inflight wifi service                                       0.347605
# Departure/Arrival time convenient                           1.000000
# Ease of Online booking                                      0.441049
# Gate location                                               0.447268
# Food and drink                                             -0.000090
# Online boarding                                             0.073178
# Seat comfort                                                0.006307
# Inflight entertainment                                     -0.007846
# On-board service                                            0.067430
# Leg room service                                            0.010224
# Baggage handling                                            0.071769
# Checkin service                                             0.089484
# Cleanliness                                                 0.007722
# Departure Delay in Minutes                                  0.000110
# Arrival Delay in Minutes                                   -0.002199
# y                                                          -0.055496
#
#                                    Ease of Online booking  Gate location  \
# Age                                              0.021483      -0.000824
# Flight Distance                                  0.063436       0.005740
# Inflight wifi service                            0.715012       0.340091
# Departure/Arrival time convenient                0.441049       0.447268
# Ease of Online booking                           1.000000       0.461326
# Gate location                                    0.461326       1.000000
# Food and drink                                   0.031566      -0.002251
# Online boarding                                  0.405302       0.003700
# Seat comfort                                     0.028880       0.003563
# Inflight entertainment                           0.048278       0.004402
# On-board service                                 0.040310      -0.028593
# Leg room service                                 0.108684      -0.004734
# Baggage handling                                 0.040951       0.002078
# Checkin service                                  0.008252      -0.038156
# Cleanliness                                      0.014708      -0.006263
# Departure Delay in Minutes                      -0.005774       0.006053
# Arrival Delay in Minutes                        -0.007096       0.005932
# y                                                0.169288      -0.002206
#
#                                    Food and drink  Online boarding  \
# Age                                      0.023406         0.208399
# Flight Distance                          0.055859         0.211447
# Inflight wifi service                    0.133316         0.458714
# Departure/Arrival time convenient       -0.000090         0.073178
# Ease of Online booking                   0.031566         0.405302
# Gate location                           -0.002251         0.003700
# Food and drink                           1.000000         0.234956
# Online boarding                          0.234956         1.000000
# Seat comfort                             0.575119         0.419520
# Inflight entertainment                   0.623271         0.284512
# On-board service                         0.059023         0.154184
# Leg room service                         0.033797         0.123405
# Baggage handling                         0.035810         0.083953
# Checkin service                          0.083151         0.204052
# Cleanliness                              0.658304         0.329480
# Departure Delay in Minutes              -0.028073        -0.016926
# Arrival Delay in Minutes                -0.030628        -0.019800
# y                                        0.209757         0.503448
#
#                                    Seat comfort  Inflight entertainment  \
# Age                                    0.160770                0.074734
# Flight Distance                        0.156211                0.128991
# Inflight wifi service                  0.122114                0.209914
# Departure/Arrival time convenient      0.006307               -0.007846
# Ease of Online booking                 0.028880                0.048278
# Gate location                          0.003563                0.004402
# Food and drink                         0.575119                0.623271
# Online boarding                        0.419520                0.284512
# Seat comfort                           1.000000                0.612330
# Inflight entertainment                 0.612330                1.000000
# On-board service                       0.131799                0.420629
# Leg room service                       0.103900                0.301805
# Baggage handling                       0.074397                0.379780
# Checkin service                        0.188156                0.117699
# Cleanliness                            0.678926                0.692337
# Departure Delay in Minutes            -0.027447               -0.026984
# Arrival Delay in Minutes              -0.030056               -0.030505
# y                                      0.348821                0.396654
#
#                                    On-board service  Leg room service  \
# Age                                        0.057528          0.038206
# Flight Distance                            0.113503          0.137181
# Inflight wifi service                      0.121420          0.159570
# Departure/Arrival time convenient          0.067430          0.010224
# Ease of Online booking                     0.040310          0.108684
# Gate location                             -0.028593         -0.004734
# Food and drink                             0.059023          0.033797
# Online boarding                            0.154184          0.123405
# Seat comfort                               0.131799          0.103900
# Inflight entertainment                     0.420629          0.301805
# On-board service                           1.000000          0.359508
# Leg room service                           0.359508          1.000000
# Baggage handling                           0.521066          0.372365
# Checkin service                            0.247995          0.152628
# Cleanliness                                0.123528          0.096289
# Departure Delay in Minutes                -0.029847          0.012903
# Arrival Delay in Minutes                  -0.033875          0.010293
# y                                          0.323291          0.311889
#
#                                    Baggage handling  Checkin service  \
# Age                                       -0.050065         0.034467
# Flight Distance                            0.067924         0.075491
# Inflight wifi service                      0.121047         0.043056
# Departure/Arrival time convenient          0.071769         0.089484
# Ease of Online booking                     0.040951         0.008252
# Gate location                              0.002078        -0.038156
# Food and drink                             0.035810         0.083151
# Online boarding                            0.083953         0.204052
# Seat comfort                               0.074397         0.188156
# Inflight entertainment                     0.379780         0.117699
# On-board service                           0.521066         0.247995
# Leg room service                           0.372365         0.152628
# Baggage handling                           1.000000         0.234794
# Checkin service                            0.234794         1.000000
# Cleanliness                                0.096408         0.172763
# Departure Delay in Minutes                -0.005237        -0.017602
# Arrival Delay in Minutes                  -0.008963        -0.021125
# y                                          0.249289         0.238373
#
#                                    Cleanliness  Departure Delay in Minutes  \
# Age                                   0.054714                   -0.008189
# Flight Distance                       0.092565                    0.003788
# Inflight wifi service                 0.130730                   -0.016020
# Departure/Arrival time convenient     0.007722                    0.000110
# Ease of Online booking                0.014708                   -0.005774
# Gate location                        -0.006263                    0.006053
# Food and drink                        0.658304                   -0.028073
# Online boarding                       0.329480                   -0.016926
# Seat comfort                          0.678926                   -0.027447
# Inflight entertainment                0.692337                   -0.026984
# On-board service                      0.123528                   -0.029847
# Leg room service                      0.096289                    0.012903
# Baggage handling                      0.096408                   -0.005237
# Checkin service                       0.172763                   -0.017602
# Cleanliness                           1.000000                   -0.014278
# Departure Delay in Minutes           -0.014278                    1.000000
# Arrival Delay in Minutes             -0.016288                    0.959670
# y                                     0.308044                   -0.050741
#
#                                    Arrival Delay in Minutes         y
# Age                                               -0.010931  0.134074
# Flight Distance                                   -0.000151  0.297777
# Inflight wifi service                             -0.017754  0.283292
# Departure/Arrival time convenient                 -0.002199 -0.055496
# Ease of Online booking                            -0.007096  0.169288
# Gate location                                      0.005932 -0.002206
# Food and drink                                    -0.030628  0.209757
# Online boarding                                   -0.019800  0.503448
# Seat comfort                                      -0.030056  0.348821
# Inflight entertainment                            -0.030505  0.396654
# On-board service                                  -0.033875  0.323291
# Leg room service                                   0.010293  0.311889
# Baggage handling                                  -0.008963  0.249289
# Checkin service                                   -0.021125  0.238373
# Cleanliness                                       -0.016288  0.308044
# Departure Delay in Minutes                         0.959670 -0.050741
# Arrival Delay in Minutes                           1.000000 -0.057802
# y                                                 -0.057802  1.000000

# %%
##
sns.heatmap(corr_matrix.round(2), annot=True, cmap="crest");

# %%
sns.scatterplot(data=X_y_train, x='Online boarding', y='y');

# %%
col_x = 'Online boarding'
col_y = 'y'

X_y_train \
    .groupby([col_x, col_y], as_index=False) \
    .agg({'Gender': 'count'})
# Out:
#     Online boarding      y  Gender
# 0                 0  False    1022
# 1                 0   True    1297
# 2                 1  False    8516
# 3                 1   True    1358
# 4                 2  False   14539
# 5                 2   True    1859
# 6                 3  False   17588
# 7                 3   True    2808
# 8                 4  False   10873
# 9                 4   True   18049
# 10                5  False    2489
# 11                5   True   17012

# %%
col_x = 'Online boarding'
col_y = 'y'

X_y_train \
    .groupby([col_x, col_y], as_index=False) \
    .agg({'Gender': 'count'}) \
    .pivot(col_y, col_x, 'Gender')
# Out:
# Online boarding     0     1      2      3      4      5
# y
# False            1022  8516  14539  17588  10873   2489
# True             1297  1358   1859   2808  18049  17012

# %% [markdown]
# # Подготовка факторов

# %% [markdown]
# ## Отбор факторов

# %%
numeric_factors = ['Age', 'Flight Distance', 'Departure Delay in Minutes', 'Arrival Delay in Minutes']

# %%
categorical_factors = ['Gender', 'Customer Type', 'Type of Travel', 'Class', 'Inflight wifi service', 'Departure/Arrival time convenient', 'Ease of Online booking', 'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
                       'Inflight entertainment', 'On-board service', 'Leg room service', 'Baggage handling', 'Checkin service', 'Cleanliness']

# %%
X_y_train[numeric_factors + ['y']].corr()
# Out:
#                                  Age  Flight Distance  \
# Age                         1.000000         0.098764
# Flight Distance             0.098764         1.000000
# Departure Delay in Minutes -0.008189         0.003788
# Arrival Delay in Minutes   -0.010931        -0.000151
# y                           0.134074         0.297777
#
#                             Departure Delay in Minutes  \
# Age                                          -0.008189
# Flight Distance                               0.003788
# Departure Delay in Minutes                    1.000000
# Arrival Delay in Minutes                      0.959670
# y                                            -0.050741
#
#                             Arrival Delay in Minutes         y
# Age                                        -0.010931  0.134074
# Flight Distance                            -0.000151  0.297777
# Departure Delay in Minutes                  0.959670 -0.050741
# Arrival Delay in Minutes                    1.000000 -0.057802
# y                                          -0.057802  1.000000

# %%
sns.scatterplot(x=X_y_train['Departure Delay in Minutes'], y=X_y_train['Arrival Delay in Minutes']);

# %%
X_y_train[X_y_train['Departure Delay in Minutes'] > 60][numeric_factors + ['y']].corr()
# Out:
#                                  Age  Flight Distance  \
# Age                         1.000000         0.095074
# Flight Distance             0.095074         1.000000
# Departure Delay in Minutes -0.018401         0.049094
# Arrival Delay in Minutes   -0.023567         0.034809
# y                           0.133101         0.295254
#
#                             Departure Delay in Minutes  \
# Age                                          -0.018401
# Flight Distance                               0.049094
# Departure Delay in Minutes                    1.000000
# Arrival Delay in Minutes                      0.955174
# y                                             0.006485
#
#                             Arrival Delay in Minutes         y
# Age                                        -0.023567  0.133101
# Flight Distance                             0.034809  0.295254
# Departure Delay in Minutes                  0.955174  0.006485
# Arrival Delay in Minutes                    1.000000  0.008461
# y                                           0.008461  1.000000

# %%
## Delay не влияют на y, отбросим. Почему не влияют?
excluded_numeric_factors = ['Departure Delay in Minutes', 'Arrival Delay in Minutes']

# %%
X_y_train.groupby('Inflight wifi service', as_index=False).agg({'y': ['mean', 'count']})
# Out:
#   Inflight wifi service         y
#                              mean  count
# 0                     0  0.997626   2949
# 1                     1  0.329143  16786
# 2                     2  0.246941  24107
# 3                     3  0.251605  24145
# 4                     4  0.600570  18599
# 5                     5  0.990207  10824

# %%
## если разница средних хотя бы в одной паре подгрупп по этому фактору больше 0,2, то считаем этот фактор полезным?
## Берем в рассчет только подгруппы с числом людей > 5000
useful_categorical_factors = []

for factor in categorical_factors:
    factor_df = X_y_train.groupby(factor, as_index=False).agg({'y': ['mean', 'count']})
    factor_df = factor_df[factor_df[('y', 'count')] > 5000]
    
    diffs = []
    
    ## не перемудрили? Надо было разницу max и min
    for _, row_1 in factor_df.iterrows():
        for _, row_2 in factor_df.iterrows():
            diffs.append(abs(row_1[('y', 'mean')] - row_2[('y', 'mean')]))
            
    if max(diffs) > 0.2:
        useful_categorical_factors.append(factor)

# %%
len(categorical_factors)
# Out:
# 17

# %%
len(useful_categorical_factors)
# Out:
# 15

# %%
X_y_train[useful_categorical_factors + ['y']].corr()
# Out:
#                         Inflight wifi service  Ease of Online booking  \
# Inflight wifi service                1.000000                0.715012
# Ease of Online booking               0.715012                1.000000
# Gate location                        0.340091                0.461326
# Food and drink                       0.133316                0.031566
# Online boarding                      0.458714                0.405302
# Seat comfort                         0.122114                0.028880
# Inflight entertainment               0.209914                0.048278
# On-board service                     0.121420                0.040310
# Leg room service                     0.159570                0.108684
# Baggage handling                     0.121047                0.040951
# Checkin service                      0.043056                0.008252
# Cleanliness                          0.130730                0.014708
# y                                    0.283292                0.169288
#
#                         Gate location  Food and drink  Online boarding  \
# Inflight wifi service        0.340091        0.133316         0.458714
# Ease of Online booking       0.461326        0.031566         0.405302
# Gate location                1.000000       -0.002251         0.003700
# Food and drink              -0.002251        1.000000         0.234956
# Online boarding              0.003700        0.234956         1.000000
# Seat comfort                 0.003563        0.575119         0.419520
# Inflight entertainment       0.004402        0.623271         0.284512
# On-board service            -0.028593        0.059023         0.154184
# Leg room service            -0.004734        0.033797         0.123405
# Baggage handling             0.002078        0.035810         0.083953
# Checkin service             -0.038156        0.083151         0.204052
# Cleanliness                 -0.006263        0.658304         0.329480
# y                           -0.002206        0.209757         0.503448
#
#                         Seat comfort  Inflight entertainment  \
# Inflight wifi service       0.122114                0.209914
# Ease of Online booking      0.028880                0.048278
# Gate location               0.003563                0.004402
# Food and drink              0.575119                0.623271
# Online boarding             0.419520                0.284512
# Seat comfort                1.000000                0.612330
# Inflight entertainment      0.612330                1.000000
# On-board service            0.131799                0.420629
# Leg room service            0.103900                0.301805
# Baggage handling            0.074397                0.379780
# Checkin service             0.188156                0.117699
# Cleanliness                 0.678926                0.692337
# y                           0.348821                0.396654
#
#                         On-board service  Leg room service  Baggage handling  \
# Inflight wifi service           0.121420          0.159570          0.121047
# Ease of Online booking          0.040310          0.108684          0.040951
# Gate location                  -0.028593         -0.004734          0.002078
# Food and drink                  0.059023          0.033797          0.035810
# Online boarding                 0.154184          0.123405          0.083953
# Seat comfort                    0.131799          0.103900          0.074397
# Inflight entertainment          0.420629          0.301805          0.379780
# On-board service                1.000000          0.359508          0.521066
# Leg room service                0.359508          1.000000          0.372365
# Baggage handling                0.521066          0.372365          1.000000
# Checkin service                 0.247995          0.152628          0.234794
# Cleanliness                     0.123528          0.096289          0.096408
# y                               0.323291          0.311889          0.249289
#
#                         Checkin service  Cleanliness         y
# Inflight wifi service          0.043056     0.130730  0.283292
# Ease of Online booking         0.008252     0.014708  0.169288
# Gate location                 -0.038156    -0.006263 -0.002206
# Food and drink                 0.083151     0.658304  0.209757
# Online boarding                0.204052     0.329480  0.503448
# Seat comfort                   0.188156     0.678926  0.348821
# Inflight entertainment         0.117699     0.692337  0.396654
# On-board service               0.247995     0.123528  0.323291
# Leg room service               0.152628     0.096289  0.311889
# Baggage handling               0.234794     0.096408  0.249289
# Checkin service                1.000000     0.172763  0.238373
# Cleanliness                    0.172763     1.000000  0.308044
# y                              0.238373     0.308044  1.000000

# %%
sns.scatterplot(data=X_y_train, x='Inflight wifi service', y='Ease of Online booking');

# %%
col_x = 'Inflight wifi service'
col_y = 'Ease of Online booking'

X_y_train \
    .groupby([col_x, col_y], as_index=False) \
    .agg({'Gender': 'count'}) \
    .pivot(col_y, col_x, 'Gender')
# Out:
# Inflight wifi service        0        1        2        3        4       5
# Ease of Online booking
# 0                       2750.0    778.0    291.0    271.0    140.0    53.0
# 1                        194.0  12137.0   1609.0    970.0    978.0   544.0
# 2                          NaN   1260.0  17454.0   1972.0   1157.0   685.0
# 3                          1.0    840.0   2060.0  17596.0   1536.0   685.0
# 4                          1.0    885.0   1352.0   2040.0  13112.0   887.0
# 5                          3.0    886.0   1341.0   1296.0   1676.0  7970.0

# %%
excluded_categorical_factors = ['Ease of Online booking', 'Gate location', 'Food and drink', 'Seat comfort', 'Baggage handling', 'Cleanliness']

# %%
len(categorical_factors)
# Out:
# 17

# %%
len(excluded_categorical_factors)
# Out:
# 6

# %%
numeric_factors_to_use = [x for x in numeric_factors if x not in excluded_numeric_factors]
categorical_factors_to_use = [x for x in categorical_factors if x not in excluded_categorical_factors]

# %%
numeric_factors_to_use
# Out:
# ['Age', 'Flight Distance']

# %%
categorical_factors_to_use
# Out:
# ['Gender',
#  'Customer Type',
#  'Type of Travel',
#  'Class',
#  'Inflight wifi service',
#  'Departure/Arrival time convenient',
#  'Online boarding',
#  'Inflight entertainment',
#  'On-board service',
#  'Leg room service',
#  'Checkin service']

# %%
X_y_train_useful_factors = X_y_train[categorical_factors_to_use + numeric_factors_to_use + ['y']]

# %% [markdown]
# ## Преобразование факторов

# %%
X_y_train_useful_factors.head()
# Out:
#        Gender      Customer Type   Type of Travel     Class  \
# 2049     Male     Loyal Customer  Business travel       Eco
# 49176    Male  disloyal Customer  Business travel       Eco
# 38346  Female     Loyal Customer  Business travel  Business
# 36699    Male     Loyal Customer  Business travel       Eco
# 20521  Female     Loyal Customer  Personal Travel       Eco
#
#        Inflight wifi service  Departure/Arrival time convenient  \
# 2049                       3                                  2
# 49176                      1                                  1
# 38346                      5                                  5
# 36699                      3                                  4
# 20521                      3                                  2
#
#        Online boarding  Inflight entertainment  On-board service  \
# 2049                 3                       3                 3
# 49176                1                       4                 1
# 38346                5                       4                 4
# 36699                3                       3                 3
# 20521                2                       3                 3
#
#        Leg room service  Checkin service  Age  Flight Distance      y
# 2049                  2                3   41              187  False
# 49176                 1                2   14             1310  False
# 38346                 4                4   43              925   True
# 36699                 3                1   50              925  False
# 20521                 3                1   55              460  False

# %%
gender_encoder = BinaryEncoder()
gender_encoder.fit(X_y_train_useful_factors['Gender'])
# Out:
# BinaryEncoder(cols=['Gender'],
#               mapping=[{'col': 'Gender',
#                         'mapping':     Gender_0  Gender_1
#  1         0         1
#  2         1         0
# -1         0         0
# -2         0         0}])

# %%
gender_encoder.transform(X_y_train_useful_factors['Gender'])
# Out:
#         Gender_0  Gender_1
# 2049           0         1
# 49176          0         1
# 38346          1         0
# 36699          0         1
# 20521          1         0
# ...          ...       ...
# 45891          0         1
# 117952         0         1
# 42613          0         1
# 43567          1         0
# 68268          1         0
#
# [97410 rows x 2 columns]

# %%
## попробовали на одной колонке, теперь на двух сразу
gender_type_of_travel_encoder = BinaryEncoder()
gender_type_of_travel_encoder.fit(X_y_train_useful_factors[['Gender', 'Type of Travel']])
# Out:
# BinaryEncoder(cols=['Gender', 'Type of Travel'],
#               mapping=[{'col': 'Gender',
#                         'mapping':     Gender_0  Gender_1
#  1         0         1
#  2         1         0
# -1         0         0
# -2         0         0},
#                        {'col': 'Type of Travel',
#                         'mapping':     Type of Travel_0  Type of Travel_1
#  1                 0                 1
#  2                 1                 0
# -1                 0                 0
# -2                 0                 0}])

# %%
## перекодируем 2 колонки "бинарно"
gender_type_of_travel_encoded = gender_type_of_travel_encoder\
    .transform(X_y_train_useful_factors[['Gender', 'Type of Travel']])

for col in gender_type_of_travel_encoded:
    X_y_train_useful_factors[col] = gender_type_of_travel_encoded[col]
    
X_y_train_useful_factors = X_y_train_useful_factors.drop(columns=['Gender', 'Type of Travel'])

# %%
X_y_train_useful_factors.head()
# Out:
#            Customer Type     Class  Inflight wifi service  \
# 2049      Loyal Customer       Eco                      3
# 49176  disloyal Customer       Eco                      1
# 38346     Loyal Customer  Business                      5
# 36699     Loyal Customer       Eco                      3
# 20521     Loyal Customer       Eco                      3
#
#        Departure/Arrival time convenient  Online boarding  \
# 2049                                   2                3
# 49176                                  1                1
# 38346                                  5                5
# 36699                                  4                3
# 20521                                  2                2
#
#        Inflight entertainment  On-board service  Leg room service  \
# 2049                        3                 3                 2
# 49176                       4                 1                 1
# 38346                       4                 4                 4
# 36699                       3                 3                 3
# 20521                       3                 3                 3
#
#        Checkin service  Age  Flight Distance      y  Gender_0  Gender_1  \
# 2049                 3   41              187  False         0         1
# 49176                2   14             1310  False         0         1
# 38346                4   43              925   True         1         0
# 36699                1   50              925  False         0         1
# 20521                1   55              460  False         1         0
#
#        Type of Travel_0  Type of Travel_1
# 2049                  0                 1
# 49176                 0                 1
# 38346                 0                 1
# 36699                 0                 1
# 20521                 1                 0

# %%
target_encoded_categories = [x for x in categorical_factors_to_use if x not in ['Gender', 'Type of Travel']]

# %%
for col in target_encoded_categories:
    X_y_train_useful_factors[col] = X_y_train_useful_factors[col].astype('category')

# %%
## всем остальным колонкам назначим тип category
X_y_train_useful_factors.dtypes
# Out:
# Customer Type                        category
# Class                                category
# Inflight wifi service                category
# Departure/Arrival time convenient    category
# Online boarding                      category
# Inflight entertainment               category
# On-board service                     category
# Leg room service                     category
# Checkin service                      category
# Age                                     int64
# Flight Distance                         int64
# y                                        bool
# Gender_0                                int64
# Gender_1                                int64
# Type of Travel_0                        int64
# Type of Travel_1                        int64
# dtype: object

# %%
## теперь категориальные факторы подвергнем целевому кодированию
target_encoder = TargetEncoder()
target_encoder.fit(X_y_train_useful_factors[target_encoded_categories], y=X_y_train_useful_factors['y'])
# Out:
# TargetEncoder(cols=['Customer Type', 'Class', 'Inflight wifi service',
#                     'Departure/Arrival time convenient', 'Online boarding',
#                     'Inflight entertainment', 'On-board service',
#                     'Leg room service', 'Checkin service'])

# %%
target_encoder.transform(X_y_train_useful_factors[target_encoded_categories])
# Out:
#         Customer Type     Class  Inflight wifi service  \
# 2049         0.478736  0.188327               0.251605
# 49176        0.240164  0.188327               0.329143
# 38346        0.478736  0.694691               0.990207
# 36699        0.478736  0.188327               0.251605
# 20521        0.478736  0.188327               0.251605
# ...               ...       ...                    ...
# 45891        0.478736  0.694691               0.251605
# 117952       0.478736  0.694691               0.251605
# 42613        0.478736  0.188327               0.990207
# 43567        0.478736  0.188327               0.246941
# 68268        0.478736  0.188327               0.251605
#
#         Departure/Arrival time convenient  Online boarding  \
# 2049                             0.443421         0.137674
# 49176                            0.492300         0.137533
# 38346                            0.424992         0.872366
# 36699                            0.388344         0.137674
# 20521                            0.443421         0.113367
# ...                                   ...              ...
# 45891                            0.424992         0.872366
# 117952                           0.441579         0.872366
# 42613                            0.424992         0.872366
# 43567                            0.424992         0.872366
# 68268                            0.424992         0.137674
#
#         Inflight entertainment  On-board service  Leg room service  \
# 2049                  0.273650          0.316771          0.278303
# 49176                 0.610346          0.196860          0.205081
# 38346                 0.610346          0.536111          0.580755
# 36699                 0.273650          0.316771          0.276713
# 20521                 0.273650          0.316771          0.276713
# ...                        ...               ...               ...
# 45891                 0.650755          0.648188          0.616631
# 117952                0.650755          0.648188          0.278303
# 42613                 0.273650          0.536111          0.616631
# 43567                 0.650755          0.648188          0.278303
# 68268                 0.215678          0.648188          0.616631
#
#         Checkin service
# 2049           0.448453
# 49176          0.250846
# 38346          0.460151
# 36699          0.242364
# 20521          0.242364
# ...                 ...
# 45891          0.250846
# 117952         0.460151
# 42613          0.448453
# 43567          0.460151
# 68268          0.460151
#
# [97410 rows x 9 columns]

# %%
X_y_train_useful_factors.groupby('Customer Type').agg({'y': 'mean'})
# Out:
#                           y
# Customer Type
# Loyal Customer     0.478736
# disloyal Customer  0.240164

# %%
categorical_factors_encoded = target_encoder\
    .transform(X_y_train_useful_factors[target_encoded_categories])

for col in categorical_factors_encoded:
    X_y_train_useful_factors[col] = categorical_factors_encoded[col]

# %%
X_y_train_useful_factors
# Out:
#         Customer Type     Class  Inflight wifi service  \
# 2049         0.478736  0.188327               0.251605
# 49176        0.240164  0.188327               0.329143
# 38346        0.478736  0.694691               0.990207
# 36699        0.478736  0.188327               0.251605
# 20521        0.478736  0.188327               0.251605
# ...               ...       ...                    ...
# 45891        0.478736  0.694691               0.251605
# 117952       0.478736  0.694691               0.251605
# 42613        0.478736  0.188327               0.990207
# 43567        0.478736  0.188327               0.246941
# 68268        0.478736  0.188327               0.251605
#
#         Departure/Arrival time convenient  Online boarding  \
# 2049                             0.443421         0.137674
# 49176                            0.492300         0.137533
# 38346                            0.424992         0.872366
# 36699                            0.388344         0.137674
# 20521                            0.443421         0.113367
# ...                                   ...              ...
# 45891                            0.424992         0.872366
# 117952                           0.441579         0.872366
# 42613                            0.424992         0.872366
# 43567                            0.424992         0.872366
# 68268                            0.424992         0.137674
#
#         Inflight entertainment  On-board service  Leg room service  \
# 2049                  0.273650          0.316771          0.278303
# 49176                 0.610346          0.196860          0.205081
# 38346                 0.610346          0.536111          0.580755
# 36699                 0.273650          0.316771          0.276713
# 20521                 0.273650          0.316771          0.276713
# ...                        ...               ...               ...
# 45891                 0.650755          0.648188          0.616631
# 117952                0.650755          0.648188          0.278303
# 42613                 0.273650          0.536111          0.616631
# 43567                 0.650755          0.648188          0.278303
# 68268                 0.215678          0.648188          0.616631
#
#         Checkin service  Age  Flight Distance      y  Gender_0  Gender_1  \
# 2049           0.448453   41              187  False         0         1
# 49176          0.250846   14             1310  False         0         1
# 38346          0.460151   43              925   True         1         0
# 36699          0.242364   50              925  False         0         1
# 20521          0.242364   55              460  False         1         0
# ...                 ...  ...              ...    ...       ...       ...
# 45891          0.250846   50             1428   True         0         1
# 117952         0.460151   19              946   True         0         1
# 42613          0.448453   19              493   True         0         1
# 43567          0.460151   69              925  False         1         0
# 68268          0.460151   32              352  False         1         0
#
#         Type of Travel_0  Type of Travel_1
# 2049                   0                 1
# 49176                  0                 1
# 38346                  0                 1
# 36699                  0                 1
# 20521                  1                 0
# ...                  ...               ...
# 45891                  0                 1
# 117952                 0                 1
# 42613                  1                 0
# 43567                  1                 0
# 68268                  1                 0
#
# [97410 rows x 16 columns]

# %%
X_y_train_useful_factors['Flight Distance'].max()
# Out:
# 4983

# %%
## нормализуем все данные (они ж все числовые)
scaler = StandardScaler()
scaler.fit(X_y_train_useful_factors.drop(columns='y'))
# Out:
# StandardScaler()

# %%
X_y_train_useful_factors[X_y_train_useful_factors.drop(columns='y').columns] = \
    scaler.transform(X_y_train_useful_factors.drop(columns='y'))

# %%
X_y_train_useful_factors
# Out:
#         Customer Type     Class  Inflight wifi service  \
# 2049         0.473129 -0.991014              -0.703202
# 49176       -2.113587 -0.991014              -0.406052
# 38346        0.473129  1.042498               2.127330
# 36699        0.473129 -0.991014              -0.703202
# 20521        0.473129 -0.991014              -0.703202
# ...               ...       ...                    ...
# 45891        0.473129  1.042498              -0.703202
# 117952       0.473129  1.042498              -0.703202
# 42613        0.473129 -0.991014               2.127330
# 43567        0.473129 -0.991014              -0.721076
# 68268        0.473129 -0.991014              -0.703202
#
#         Departure/Arrival time convenient  Online boarding  \
# 2049                             0.240835        -0.969222
# 49176                            1.655446        -0.969682
# 38346                           -0.292515         1.424925
# 36699                           -1.353132        -0.969222
# 20521                            0.240835        -1.048430
# ...                                   ...              ...
# 45891                           -0.292515         1.424925
# 117952                           0.187523         1.424925
# 42613                           -0.292515         1.424925
# 43567                           -0.292515         1.424925
# 68268                           -0.292515        -0.969222
#
#         Inflight entertainment  On-board service  Leg room service  \
# 2049                 -0.776054         -0.715026         -0.928639
# 49176                 0.842377         -1.439609         -1.362309
# 38346                 0.842377          0.610381          0.862665
# 36699                -0.776054         -0.715026         -0.938060
# 20521                -0.776054         -0.715026         -0.938060
# ...                        ...               ...               ...
# 45891                 1.036619          1.287634          1.075145
# 117952                1.036619          1.287634         -0.928639
# 42613                -0.776054          0.610381          1.075145
# 43567                 1.036619          1.287634         -0.928639
# 68268                -1.054715          1.287634          1.075145
#
#         Checkin service       Age  Flight Distance      y  Gender_0  Gender_1  \
# 2049           0.107145  0.103861        -1.005799  False -1.016020  1.016020
# 49176         -1.478325 -1.680678         0.120675  False -1.016020  1.016020
# 38346          0.200998  0.236049        -0.265516   True  0.984233 -0.984233
# 36699         -1.546384  0.698707        -0.265516  False -1.016020  1.016020
# 20521         -1.546384  1.029177        -0.731955  False  0.984233 -0.984233
# ...                 ...       ...              ...    ...       ...       ...
# 45891         -1.478325  0.698707         0.239040   True -1.016020  1.016020
# 117952         0.200998 -1.350208        -0.244451   True -1.016020  1.016020
# 42613          0.107145 -1.350208        -0.698853   True -1.016020  1.016020
# 43567          0.200998  1.954494        -0.265516  False  0.984233 -0.984233
# 68268          0.200998 -0.490986        -0.840289  False  0.984233 -0.984233
#
#         Type of Travel_0  Type of Travel_1
# 2049           -0.669201          0.669201
# 49176          -0.669201          0.669201
# 38346          -0.669201          0.669201
# 36699          -0.669201          0.669201
# 20521           1.494319         -1.494319
# ...                  ...               ...
# 45891          -0.669201          0.669201
# 117952         -0.669201          0.669201
# 42613           1.494319         -1.494319
# 43567           1.494319         -1.494319
# 68268           1.494319         -1.494319
#
# [97410 rows x 16 columns]

# %%
X_train = X_y_train_useful_factors.drop(columns='y')

# %%
scaler.transform(X_y_train_useful_factors.drop(columns='y'))[:, 2]
# Out:
# array([-4.36228951, -3.22352969,  6.48510796, ...,  6.48510796,
#        -4.43078925, -4.36228951])

# %% [markdown]
# # Создание модели

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, random_state=1000)

# %%
model = LogisticRegression(penalty='none')

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression(penalty='none')

# %%
model.predict(X_train)
# Out:
# array([ True,  True,  True, ...,  True,  True, False])

# %%
model.predict_proba(X_train)
# Out:
# array([[0.00569162, 0.99430838],
#        [0.00185702, 0.99814298],
#        [0.00874158, 0.99125842],
#        ...,
#        [0.17195501, 0.82804499],
#        [0.44257189, 0.55742811],
#        [0.99747149, 0.00252851]])

# %%
model.predict_proba(X_train)[:, 1] >= 0.5
# Out:
# array([ True,  True,  True, ...,  True,  True, False])

# %%
pred_arr = model.predict_proba(X_train)[:, 1] >= 0.5

# %%
pred_arr == model.predict(X_train)
# Out:
# array([ True,  True,  True, ...,  True,  True,  True])

# %%
(pred_arr == model.predict(X_train)).sum()
# Out:
# 73057

# %%
(pred_arr == model.predict(X_train)).sum() == len(pred_arr)
# Out:
# True

# %%
# accuracy
model.score(X_train, y_train)
# Out:
# 0.9217597218610126

# %%
accuracy_score(y_train, model.predict(X_train))
# Out:
# 0.9217597218610126

# %%
precision_score(y_train, model.predict(X_train))
# Out:
# 0.9122773718009554

# %%
recall_score(y_train, model.predict(X_train))
# Out:
# 0.9073975016519304

# %%
f1_score(y_train, model.predict(X_train))
# Out:
# 0.9098308934881374

# %%
f1_score(y_val, model.predict(X_val))
# Out:
# 0.9128913269649107

# %%
## уровень отсечки оптимальный будем искать
best_threshold = None
best_f1 = -float('inf')

probabilities = model.predict_proba(X_val)[:, 1]

# %%
probabilities > 0.5
# Out:
# array([ True, False, False, ...,  True,  True, False])

# %%
best_threshold = None
best_f1 = -float('inf')

probabilities = model.predict_proba(X_val)[:, 1]

for t in range(0, 1001):
    threshold = 0.001 * t
    
    y_val_pred = probabilities > threshold
    f1 = f1_score(y_val, y_val_pred)
    
    if f1 > best_f1:
        best_f1 = f1
        best_threshold = threshold

# %%
best_f1
# Out:
# 0.9129509669487921

# %%
best_threshold
# Out:
# 0.499

# %% [markdown]
# # Оценка качества модели

# %%
### X_test надо предобработать так же, как и X_train

# %%
X_test_useful_factors = X_test[categorical_factors_to_use + numeric_factors_to_use]

# %%
gender_type_of_travel_encoded = gender_type_of_travel_encoder\
    .transform(X_test_useful_factors[['Gender', 'Type of Travel']])

for col in gender_type_of_travel_encoded:
    X_test_useful_factors[col] = gender_type_of_travel_encoded[col]
    
X_test_useful_factors = X_test_useful_factors.drop(columns=['Gender', 'Type of Travel'])

# %%
categorical_factors_encoded = target_encoder\
    .transform(X_test_useful_factors[target_encoded_categories])

for col in categorical_factors_encoded:
    X_test_useful_factors[col] = categorical_factors_encoded[col]

# %%
X_test_useful_factors[X_test_useful_factors.columns] = scaler.transform(X_test_useful_factors)

# %%
X_test_useful_factors
# Out:
#         Customer Type     Class  Inflight wifi service  \
# 125669       0.473129 -0.991014              -0.703202
# 90648        0.473129  1.042498              -0.703202
# 45322        0.473129 -0.991014               0.634131
# 64084        0.473129  1.042498               2.127330
# 71595        0.473129 -0.991014               0.634131
# ...               ...       ...                    ...
# 127886       0.473129  1.042498               0.634131
# 37272        0.473129  1.042498              -0.721076
# 36325        0.473129 -0.991014               2.127330
# 75258       -2.113587  1.042498              -0.406052
# 34200        0.473129  1.042498               2.155763
#
#         Departure/Arrival time convenient  Online boarding  \
# 125669                           0.240835        -0.969222
# 90648                            0.187523         0.615762
# 45322                            0.187523         0.615762
# 64084                           -0.292515        -1.048430
# 71595                            0.240835        -0.969682
# ...                                   ...              ...
# 127886                          -1.353132        -0.969682
# 37272                            0.240835         1.424925
# 36325                            0.187523         1.424925
# 75258                            1.655446        -0.969682
# 34200                            1.443770        -0.969682
#
#         Inflight entertainment  On-board service  Leg room service  \
# 125669               -1.054715         -1.075177         -0.938060
# 90648                 0.842377          0.610381          0.862665
# 45322                 0.842377         -0.715026          1.075145
# 64084                -1.406860          0.610381         -1.362309
# 71595                 0.842377          0.610381         -1.362309
# ...                        ...               ...               ...
# 127886                0.842377          0.610381          0.862665
# 37272                 1.036619          1.287634          1.075145
# 36325                 1.036619         -0.715026          0.862665
# 75258                -1.406860         -0.715026         -0.938060
# 34200                -0.776054         -0.715026         -0.938060
#
#         Checkin service       Age  Flight Distance  Gender_0  Gender_1  \
# 125669         0.107145 -1.878960        -1.137205 -1.016020  1.016020
# 90648          0.200998  0.632613         1.488894 -1.016020  1.016020
# 45322          0.200998  0.830895         0.609181 -1.016020  1.016020
# 64084         -1.546384 -0.755362        -0.511274 -1.016020  1.016020
# 71595         -1.546384  0.963083        -0.859348  0.984233 -0.984233
# ...                 ...       ...              ...       ...       ...
# 127886        -1.478325  0.566519         2.643455  0.984233 -0.984233
# 37272          1.449067  0.896989         0.504860 -1.016020  1.016020
# 36325         -1.478325 -0.557080        -0.884425 -1.016020  1.016020
# 75258          1.449067 -0.689268        -0.980722  0.984233 -0.984233
# 34200         -1.478325  1.359648        -0.928561  0.984233 -0.984233
#
#         Type of Travel_0  Type of Travel_1
# 125669          1.494319         -1.494319
# 90648          -0.669201          0.669201
# 45322          -0.669201          0.669201
# 64084          -0.669201          0.669201
# 71595           1.494319         -1.494319
# ...                  ...               ...
# 127886         -0.669201          0.669201
# 37272          -0.669201          0.669201
# 36325           1.494319         -1.494319
# 75258          -0.669201          0.669201
# 34200          -0.669201          0.669201
#
# [32470 rows x 15 columns]

# %%
print('Accuracy на тестовой выборке:', accuracy_score(y_test, model.predict(X_test_useful_factors)))
print('Precision на тестовой выборке:', precision_score(y_test, model.predict(X_test_useful_factors)))
print('Recall на тестовой выборке:', recall_score(y_test, model.predict(X_test_useful_factors)))
# Out:
# Accuracy на тестовой выборке: 0.9224822913458577
# Precision на тестовой выборке: 0.9132492113564669
# Recall на тестовой выборке: 0.906941972232111

# %%
## бутстрап. Делаем случайные выборки из тестовой и вычисляем скоры
boot_accuracies = []
boot_precisions = []
boot_recalls = []

X_y_test = X_test_useful_factors.copy(deep=True)
X_y_test['y'] = y_test

for i in range(1000):
    X_y_test_boot = X_y_test.sample(len(X_y_test), replace=True)
    X_test_boot = X_y_test_boot.drop(columns='y')
    y_test_boot = X_y_test_boot['y']
    
    predicted_probas = model.predict_proba(X_test_boot)
    y_pred = predicted_probas[:, 1] >= best_threshold
    
    boot_accuracies.append(accuracy_score(y_test_boot, y_pred))
    boot_precisions.append(precision_score(y_test_boot, y_pred))
    boot_recalls.append(recall_score(y_test_boot, y_pred))

# %%
##
sns.histplot([boot_accuracies, boot_precisions, boot_recalls]);

# %%
boot_accuracies_sorted = list(sorted(boot_accuracies))
boot_accuracies_sorted = boot_accuracies_sorted[25:975]

print('Доверительный интервал для accuracy:', 
      '(' + str(round(boot_accuracies_sorted[0], 3)) + ', ' + str(round(boot_accuracies_sorted[-1], 3)) + ')')
# Out:
# Доверительный интервал для accuracy: (0.92, 0.925)

# %%
boot_precisions_sorted = list(sorted(boot_precisions))
boot_precisions_sorted = boot_precisions_sorted[25:975]

print('Доверительный интервал для precision:', 
      '(' + str(round(boot_precisions_sorted[0], 3)) + ', ' + str(round(boot_precisions_sorted[-1], 3)) + ')')
# Out:
# Доверительный интервал для precision: (0.909, 0.918)

# %%
boot_recalls_sorted = list(sorted(boot_recalls))
boot_recalls_sorted = boot_recalls_sorted[25:975]

print('Доверительный интервал для recall:', 
      '(' + str(round(boot_recalls_sorted[0], 3)) + ', ' + str(round(boot_recalls_sorted[-1], 3)) + ')')
# Out:
# Доверительный интервал для recall: (0.902, 0.912)

# %%
len(X_y_test)
# Out:
# 32470

# %%
model.coef_
# Out:
# array([[ 9.99142636e-01,  5.49537100e-01,  1.74250499e+00,
#          2.44607461e-01,  1.10702893e+00,  2.80804053e-01,
#          4.76054119e-01,  4.35645551e-01,  5.52991199e-01,
#         -5.11284318e-02,  5.42142730e-02, -1.26821619e-03,
#          1.26821619e-03, -7.55121596e-01,  7.55121596e-01]])
